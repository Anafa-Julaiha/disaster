# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import pandas as pd

# %%
data = pd.read_csv('/content/enhanced_disaster_response_dataset.csv')
data
# Out:
#      Threat_ID  Location    Disaster  Threat_Level  Required_Soldiers  \
# 0            1    School       Flood             7                 84
# 1            2    School     Tsunami             4                 80
# 2            3    School  Earthquake             8                120
# 3            4    Office     Tsunami             5                100
# 4            5    School     Tsunami             7                140
# ..         ...       ...         ...           ...                ...
# 495        496    Office       Flood             1                 12
# 496        497  Hospital        Fire             7                 70
# 497        498      Mall     Tsunami             7                140
# 498        499  Hospital     Tsunami             9                180
# 499        500    School     Cyclone             3                 39
#
#      Casualties_Estimated  Response_Time_Hours Infrastructure_Damage  \
# 0                     112                20.52                Medium
# 1                     445                 4.14                Medium
# 2                     358                17.30                   Low
# 3                     280                13.71                  High
# 4                     116                 7.82                Medium
# ..                    ...                  ...                   ...
# 495                   164                18.31                  High
# 496                   499                17.26                Medium
# 497                   395                18.91                  High
# 498                   483                 4.29                Medium
# 499                   282                 5.70                   Low
#
#     Evacuation_Required Medical_Assistance_Needed
# 0                    No                       Yes
# 1                   Yes                       Yes
# 2                   Yes                       Yes
# 3                    No                       Yes
# 4                    No                        No
# ..                  ...                       ...
# 495                 Yes                        No
# 496                 Yes                        No
# 497                 Yes                       Yes
# 498                  No                       Yes
# 499                  No                       Yes
#
# [500 rows x 10 columns]

# %%
df = pd.DataFrame(data)
df
# Out:
#      Threat_ID  Location    Disaster  Threat_Level  Required_Soldiers  \
# 0            1    School       Flood             7                 84
# 1            2    School     Tsunami             4                 80
# 2            3    School  Earthquake             8                120
# 3            4    Office     Tsunami             5                100
# 4            5    School     Tsunami             7                140
# ..         ...       ...         ...           ...                ...
# 495        496    Office       Flood             1                 12
# 496        497  Hospital        Fire             7                 70
# 497        498      Mall     Tsunami             7                140
# 498        499  Hospital     Tsunami             9                180
# 499        500    School     Cyclone             3                 39
#
#      Casualties_Estimated  Response_Time_Hours Infrastructure_Damage  \
# 0                     112                20.52                Medium
# 1                     445                 4.14                Medium
# 2                     358                17.30                   Low
# 3                     280                13.71                  High
# 4                     116                 7.82                Medium
# ..                    ...                  ...                   ...
# 495                   164                18.31                  High
# 496                   499                17.26                Medium
# 497                   395                18.91                  High
# 498                   483                 4.29                Medium
# 499                   282                 5.70                   Low
#
#     Evacuation_Required Medical_Assistance_Needed
# 0                    No                       Yes
# 1                   Yes                       Yes
# 2                   Yes                       Yes
# 3                    No                       Yes
# 4                    No                        No
# ..                  ...                       ...
# 495                 Yes                        No
# 496                 Yes                        No
# 497                 Yes                       Yes
# 498                  No                       Yes
# 499                  No                       Yes
#
# [500 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Threat_ID                    0
# Location                     0
# Disaster                     0
# Threat_Level                 0
# Required_Soldiers            0
# Casualties_Estimated         0
# Response_Time_Hours          0
# Infrastructure_Damage        0
# Evacuation_Required          0
# Medical_Assistance_Needed    0
# dtype: int64

# %%
df.shape
# Out:
# (500, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Threat_ID                  500 non-null    int64
#  1   Location                   500 non-null    object
#  2   Disaster                   500 non-null    object
#  3   Threat_Level               500 non-null    int64
#  4   Required_Soldiers          500 non-null    int64
#  5   Casualties_Estimated       500 non-null    int64
#  6   Response_Time_Hours        500 non-null    float64
#  7   Infrastructure_Damage      500 non-null    object
#  8   Evacuation_Required        500 non-null    object
#  9   Medical_Assistance_Needed  500 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#         Threat_ID  Threat_Level  Required_Soldiers  Casualties_Estimated  \
# count  500.000000    500.000000         500.000000            500.000000
# mean   250.500000      5.430000          73.856000            259.892000
# std    144.481833      2.941156          44.759201            139.434861
# min      1.000000      1.000000          10.000000             11.000000
# 25%    125.750000      3.000000          39.000000            142.250000
# 50%    250.500000      5.000000          70.000000            261.000000
# 75%    375.250000      8.000000         104.000000            381.250000
# max    500.000000     10.000000         200.000000            499.000000
#
#        Response_Time_Hours
# count           500.000000
# mean             12.548540
# std               6.561336
# min               1.060000
# 25%               6.810000
# 50%              12.865000
# 75%              17.952500
# max              23.950000

# %%
# List of categorical columns to encode
categorical_columns = ["Location", "Disaster", "Infrastructure_Damage"]

# %%
# Apply Label Encoding only to categorical columns
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # Save encoder for future use

# %%
# Convert binary categorical columns
df["Evacuation_Required"] = df["Evacuation_Required"].map({"Yes": 1, "No": 0})
df["Medical_Assistance_Needed"] = df["Medical_Assistance_Needed"].map({"Yes": 1, "No": 0})

# %%
df
# Out:
#      Threat_ID  Location  Disaster  Threat_Level  Required_Soldiers  \
# 0            1         4         3             7                 84
# 1            2         4         4             4                 80
# 2            3         4         1             8                120
# 3            4         2         4             5                100
# 4            5         4         4             7                140
# ..         ...       ...       ...           ...                ...
# 495        496         2         3             1                 12
# 496        497         0         2             7                 70
# 497        498         1         4             7                140
# 498        499         0         4             9                180
# 499        500         4         0             3                 39
#
#      Casualties_Estimated  Response_Time_Hours  Infrastructure_Damage  \
# 0                     112                20.52                      2
# 1                     445                 4.14                      2
# 2                     358                17.30                      1
# 3                     280                13.71                      0
# 4                     116                 7.82                      2
# ..                    ...                  ...                    ...
# 495                   164                18.31                      0
# 496                   499                17.26                      2
# 497                   395                18.91                      0
# 498                   483                 4.29                      2
# 499                   282                 5.70                      1
#
#      Evacuation_Required  Medical_Assistance_Needed
# 0                      0                          1
# 1                      1                          1
# 2                      1                          1
# 3                      0                          1
# 4                      0                          0
# ..                   ...                        ...
# 495                    1                          0
# 496                    1                          0
# 497                    1                          1
# 498                    0                          1
# 499                    0                          1
#
# [500 rows x 10 columns]

# %%
x = df.drop('Required_Soldiers', axis=1).values
y = df['Required_Soldiers'].values

# %%
# Applying StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Train Random Forest Model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model.score(X_train, y_train)
# Out:
# 0.9999186394992535

# %%
# Predict and calculate accuracy
y_pred = model.predict(X_test)
accuracy = r2_score(y_test, y_pred) * 100
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# Model Accuracy: 99.95%

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train)
# Out:
# 0.8319120655446707

# %%
# Predict and calculate accuracy
y_pred = lr.predict(X_test)
accuracy = r2_score(y_test, y_pred) * 100
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# Model Accuracy: 83.03%

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.score(X_train, y_train)
# Out:
# 1.0

# %%
# Predict and calculate accuracy
y_pred = lr.predict(X_test)
accuracy = r2_score(y_test, y_pred) * 100
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# Model Accuracy: 83.03%
